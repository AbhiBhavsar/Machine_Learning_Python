# %%
import pandas as pd

# %%
#Reading the csv with pandas
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting csv with pandas
export_car_sales=car_sales.to_csv("export_car_sales.csv", index=False)
export_car_sales=pd.read_csv("export_car_sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Describing Data with Pandas

# %%
# car_sales.dtypes    #car_sales.info()
# car_sales.columns   #car_sales.describe()
# car_sales.index     #car_sales["Doors"].sum()
# len(car_sales)
# Out:
# 10

# %% [markdown]
# ### Selecting & Viewing with Pandas

# %%
#car_sales.head()   car_sales.head(7)
#car_sales.tail()   car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc and iloc (used when custom indexing is involved)
animals=pd.Series(["cat","dog","frog","bird","reptile"], index=[3,3,2,5,8])
# animals.loc[3]
# animals.iloc[3]

# %%
# view dataframe cols
car_sales["Make"]  #car_sales.Make
#we can't use 2nd syntax if col name has space in string
car_sales[car_sales["Make"]=='Toyota'] #Boolean indexing
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
# pd.crosstab(car_sales.Make,car_sales.Doors)
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# visualization
#car_sales["Odometer (KM)"].plot()
car_sales["Make"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Manipulation using pandas

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing=pd.read_csv("car-sales-missing.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0    4.0   $4,000.00
# 1   Honda    Red        87899.0    4.0   $5,000.00
# 2  Toyota   Blue        32549.0    3.0         NaN
# 3     BMW  Black        11179.0    5.0  $22,000.00
# 4  Nissan  White            NaN    4.0   $3,500.00
# 5  Toyota  Green        99213.0    NaN   $4,500.00
# 6   Honda   Blue        45698.0    4.0   $7,500.00
# 7   Honda   Blue        54738.0    4.0         NaN
# 8  Toyota  White            NaN    4.0   $6,250.00
# 9  Nissan  White        31600.0    NaN   $9,700.00

# %%
car_sales_missing["Odometer (KM)"]=car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean())
car_sales_missing #reassignign the value to data frame after the change
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White     150043.000    4.0   $4,000.00
# 1   Honda    Red      87899.000    4.0   $5,000.00
# 2  Toyota   Blue      32549.000    3.0         NaN
# 3     BMW  Black      11179.000    5.0  $22,000.00
# 4  Nissan  White      64114.875    4.0   $3,500.00
# 5  Toyota  Green      99213.000    NaN   $4,500.00
# 6   Honda   Blue      45698.000    4.0   $7,500.00
# 7   Honda   Blue      54738.000    4.0         NaN
# 8  Toyota  White      64114.875    4.0   $6,250.00
# 9  Nissan  White      31600.000    NaN   $9,700.00

# %%
#using inplace parameter for fillna
car_sales_missing.fillna(car_sales_missing["Odometer (KM)"].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour  Odometer (KM)      Doors       Price
# 0  Toyota  White     150043.000      4.000   $4,000.00
# 1   Honda    Red      87899.000      4.000   $5,000.00
# 2  Toyota   Blue      32549.000      3.000   64114.875
# 3     BMW  Black      11179.000      5.000  $22,000.00
# 4  Nissan  White      64114.875      4.000   $3,500.00
# 5  Toyota  Green      99213.000  64114.875   $4,500.00
# 6   Honda   Blue      45698.000      4.000   $7,500.00
# 7   Honda   Blue      54738.000      4.000   64114.875
# 8  Toyota  White      64114.875      4.000   $6,250.00
# 9  Nissan  White      31600.000  64114.875   $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import random
car_sales["Saftey Rating"]=random.choice([1,2,3,4,5])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Saftey Rating
# 0  Toyota  White         150043      4   $4,000.00              4
# 1   Honda    Red          87899      4   $5,000.00              4
# 2  Toyota   Blue          32549      3   $7,000.00              4
# 3     BMW  Black          11179      5  $22,000.00              4
# 4  Nissan  White         213095      4   $3,500.00              4
# 5  Toyota  Green          99213      4   $4,500.00              4
# 6   Honda   Blue          45698      4   $7,500.00              4
# 7   Honda   Blue          54738      4   $7,000.00              4
# 8  Toyota  White          60000      4   $6,250.00              4
# 9  Nissan  White          31600      4   $9,700.00              4

# %%
car_sales["Milage"]=random.random()*10
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Saftey Rating    Milage
# 0  Toyota  White         150043      4   $4,000.00              4  4.207344
# 1   Honda    Red          87899      4   $5,000.00              4  4.207344
# 2  Toyota   Blue          32549      3   $7,000.00              4  4.207344
# 3     BMW  Black          11179      5  $22,000.00              4  4.207344
# 4  Nissan  White         213095      4   $3,500.00              4  4.207344
# 5  Toyota  Green          99213      4   $4,500.00              4  4.207344
# 6   Honda   Blue          45698      4   $7,500.00              4  4.207344
# 7   Honda   Blue          54738      4   $7,000.00              4  4.207344
# 8  Toyota  White          60000      4   $6,250.00              4  4.207344
# 9  Nissan  White          31600      4   $9,700.00              4  4.207344

# %%
car_sales.drop("Saftey Rating",axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price    Milage
# 0  Toyota  White         150043      4   $4,000.00  4.207344
# 1   Honda    Red          87899      4   $5,000.00  4.207344
# 2  Toyota   Blue          32549      3   $7,000.00  4.207344
# 3     BMW  Black          11179      5  $22,000.00  4.207344
# 4  Nissan  White         213095      4   $3,500.00  4.207344
# 5  Toyota  Green          99213      4   $4,500.00  4.207344
# 6   Honda   Blue          45698      4   $7,500.00  4.207344
# 7   Honda   Blue          54738      4   $7,000.00  4.207344
# 8  Toyota  White          60000      4   $6,250.00  4.207344
# 9  Nissan  White          31600      4   $9,700.00  4.207344
